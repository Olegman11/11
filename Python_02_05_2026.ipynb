# %% [markdown]
# <a href="https://colab.research.google.com/github/Olegman11/11/blob/main/Python_02_05_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction

# %%
#My first Python program
print("Hello World")
# Out:
# Hello World

# %%
#Output my name
print("Oleh")
# Out:
# Oleh

# %%
#Using multiple print statements to output
print("Hello")
print("World")
# Out:
# Hello
# World

# %% [markdown]
# Arithmetic `operators`

# %%
#addition
444+555
# Out:
# 999

# %%
#subtraction
555-444
# Out:
# 111

# %%
#multiplication
555*2
# Out:
# 1110

# %%
#division
555/5
# Out:
# 111.0

# %% [markdown]
# Variables

# %%
# a variable is a container that can store a peice of data

name = "Oleh"
print(name)
# Out:
# Oleh

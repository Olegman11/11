# %% [markdown]
# <a href="https://colab.research.google.com/github/Olegman11/11/blob/main/f2_lesson_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# F2 Fundamentals of Programming

# %%
#My first code
# It outputs the text
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# Functions in Python

# %%
sum([5, 5, 7,9,100])
# Out:
# 126

# %% [markdown]
# A sample of an user-defined function

# %%
a=5
b=5
sum=a+b
print('sum is equil',sum)
# Out:
# sum is equil 10

# %%
def addition():
    a = 5
    b = 5
    sum = a + b
    print(sum)

# %%
addition()
# Out:
# 10

# %%
ax=5
bx=5
if ax == bx:
  print('they are equil')
  print('a=b')
# Out:
# they are equil
# a=b

# %%
def smm():
 s=20
 d=25
 sd=(s+d)
 print(sd)

# %%
#assign a value into a variable
MyName = 'Inessa'                  # string data type
MyAge = 18                         # integer data tipe
Im_a_princess = True               # boolean data type
myheight = 170.50                  # float data type
MyList = ['hello', 32, 14, True]   # list data type

# %%
# Financial simple task
loan = input('Enter principal amount = ')
Rate_loan = int(input('Enter rate of your loan in persent = '))
Rate_loan = Rate_loan / 100
Duration_years = int(input('Enter a refund lenght = '))
interest = float(loan) * float(Rate_loan) * float(Duration_years)
print(interest)
#In Python, casting (also known as type conversion) is the process of converting a variable from one data type to another.
#В Python приведение типов (также известное как преобразование типов) — это процесс преобразования переменной из одного типа данных в другой.
# Out:
# Enter principal amount = 15000
# Enter rate of your loan in persent = 5
# Enter a refund lenght = 3
# 2250.0
